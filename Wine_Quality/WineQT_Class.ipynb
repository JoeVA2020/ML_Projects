# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.drop('Id',axis=1,inplace=True)

# %%
corrilation=df.corr(numeric_only=True)
plt.figure(figsize=(12,12))
plt.title('Wine Quality Heatmap')
sns.heatmap(corrilation,annot=True,linewidths=0.5,)
# Out:
# <Axes: title={'center': 'Wine Quality Heatmap'}>

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
g=sns.barplot(x='quality',y='alcohol',hue='quality',data=df)
plt.title('Alcohol vs Quality Graph')
plt.figure(figsize=(10,10))
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df)
plt.show()

# %%
outlier_columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar','chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

def remove_outliers(df,columns):
       for col in columns:
              Q1=df[col].quantile(0.25)
              Q3=df[col].quantile(0.75)
              IQR=Q3-Q1
              
              lowerBound= Q1 - 1.5 * IQR
              upperBound= Q3 + 1.5 * IQR
              
              df=df[(df[col]>=lowerBound)&(df[col]<=upperBound)]
       return df
df_cleaned=remove_outliers(df,outlier_columns)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df_cleaned)
plt.title("After cleaning Outliers")
plt.show()

# %%
df_cleaned.shape
# Out:
# (797, 12)

# %%
df_cleaned['quality'].value_counts()
# Out:
# quality
# 5    345
# 6    336
# 7     88
# 4     18
# 8      8
# 3      2
# Name: count, dtype: int64

# %%
QualityLabels=['5','6','7','4','8','3']
plt.pie(df['quality'].value_counts(),autopct='%0.1f%%')
plt.title('Quality distribution')
plt.legend(QualityLabels)
plt.show()

# %%
#oversampling using SMOTE
from imblearn.over_sampling import RandomOverSampler
ROS=RandomOverSampler(sampling_strategy='auto', random_state=42)
x,y=ROS.fit_resample(df_cleaned.drop('quality',axis=1),df_cleaned['quality'])

# %%
df_cleaned['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# #spliting input and output
# x=df_cleaned.iloc[:,:-1].values
# y=df_cleaned.iloc[:,-1].values
np.unique(y)
# Out:
# array([3, 4, 5, 6, 7, 8])

# %%
QualityLabels=['5','6','7','4','8','3']
plt.pie(np.bincount(y),autopct='%0.1f%%')
plt.title('Quality distribution after Oversampling')
plt.legend(QualityLabels)
plt.show()

# %%
# Normalizing values in input data
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
#spliting training and test data
from sklearn.model_selection import train_test_split
xTrain,xTest,yTrain,yTest=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy')
model.fit(xTrain,yTrain)
y_pred=model.predict(xTest)

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,precision_score,f1_score,classification_report
cm=confusion_matrix(yTest,y_pred)
cmd=ConfusionMatrixDisplay(cm,display_labels=[3, 4, 5, 6, 7, 8])
cmd.plot()

# %%
print('accuracy_score :',accuracy_score(yTest,y_pred))
print(classification_report(yTest,y_pred))
# Out:
# accuracy_score : 0.8647342995169082
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00        91
#            4       0.89      1.00      0.94        95
#            5       0.68      0.66      0.67       101
#            6       0.75      0.58      0.65       119
#            7       0.89      1.00      0.94       116
#            8       0.98      1.00      0.99        99
#
#     accuracy                           0.86       621
#    macro avg       0.86      0.87      0.87       621
# weighted avg       0.86      0.86      0.86       621

# %%
##hyperparameter tuning
from sklearn.model_selection import GridSearchCV
DTC=DecisionTreeClassifier()
para={'criterion':['gini','entropy','log_loss'],'splitter':['random','best'],'random_state':[0,1,42]}
hyper=GridSearchCV(DTC,para,cv=5,scoring='accuracy')
hyper.fit(xTrain,yTrain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'random_state': [0, 1, 42],
#                          'splitter': ['random', 'best']},
#              scoring='accuracy')

# %%
print(hyper.best_params_)
# Out:
# {'criterion': 'entropy', 'random_state': 42, 'splitter': 'best'}

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier(criterion='gini',random_state=42,splitter='random')
model2.fit(xTrain,yTrain)
y_pred2=model.predict(xTest)

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,precision_score,f1_score,classification_report
cm=confusion_matrix(yTest,y_pred2)
cmd=ConfusionMatrixDisplay(cm,display_labels=[3, 4, 5, 6, 7, 8])
cmd.plot()

# %%
print('accuracy_score :',accuracy_score(yTest,y_pred2))
print(classification_report(yTest,y_pred2))
# Out:
# accuracy_score : 0.7995169082125604
#               precision    recall  f1-score   support
#
#            4       0.93      1.00      0.96       116
#            5       0.72      0.60      0.66       113
#            6       0.64      0.62      0.63        99
#            7       0.87      1.00      0.93        86
#
#     accuracy                           0.80       414
#    macro avg       0.79      0.80      0.79       414
# weighted avg       0.79      0.80      0.79       414
