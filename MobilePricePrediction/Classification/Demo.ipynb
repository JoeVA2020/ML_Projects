# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
print(df_train.info())
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Battery_Power  2000 non-null   int64
#  1   Clock_Speed    2000 non-null   float64
#  2   FC             2000 non-null   int64
#  3   Int_Memory     2000 non-null   int64
#  4   Mobile_D       2000 non-null   float64
#  5   Mobile_W       2000 non-null   int64
#  6   Cores          2000 non-null   int64
#  7   PC             2000 non-null   int64
#  8   Pixel_H        2000 non-null   int64
#  9   Pixel_W        2000 non-null   int64
#  10  Ram            2000 non-null   int64
#  11  Screen_H       2000 non-null   int64
#  12  Screen_W       2000 non-null   int64
#  13  Talk_Time      2000 non-null   int64
#  14  Four_G         2000 non-null   int64
#  15  Three_G        2000 non-null   int64
#  16  Touch_Screen   2000 non-null   int64
#  17  Dual_SIM       2000 non-null   int64
# ...

# %%
df=pd.concat((df_train,df_test),axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Battery_Power  3000 non-null   int64
#  1   Clock_Speed    3000 non-null   float64
#  2   FC             3000 non-null   int64
#  3   Int_Memory     3000 non-null   int64
#  4   Mobile_D       3000 non-null   float64
#  5   Mobile_W       3000 non-null   int64
#  6   Cores          3000 non-null   int64
#  7   PC             3000 non-null   int64
#  8   Pixel_H        3000 non-null   int64
#  9   Pixel_W        3000 non-null   int64
#  10  Ram            3000 non-null   int64
#  11  Screen_H       3000 non-null   int64
#  12  Screen_W       3000 non-null   int64
#  13  Talk_Time      3000 non-null   int64
#  14  Four_G         3000 non-null   int64
#  15  Three_G        3000 non-null   int64
#  16  Touch_Screen   3000 non-null   int64
#  17  Dual_SIM       3000 non-null   int64
# ...

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#       Battery_Power  Clock_Speed  FC  Int_Memory  Mobile_D  Mobile_W  Cores  \
# 0               842          2.2   1           7       0.6       188      2
# 1              1021          0.5   0          53       0.7       136      3
# 2               563          0.5   2          41       0.9       145      5
# 3               615          2.5   0          10       0.8       131      6
# 4              1821          1.2  13          44       0.6       141      2
# ...             ...          ...  ..         ...       ...       ...    ...
# 2995           1700          1.9   0          54       0.5       170      7
# 2996            609          1.8   0          13       0.9       186      4
# 2997           1185          1.4   1           8       0.5        80      1
# 2998           1533          0.5   0          50       0.4       171      2
# 2999           1270          0.5   4          35       0.1       140      6
#
# ...

# %%
df['Price_Range'].value_counts()
# Out:
# Price_Range
# 1    1016
# 0     984
# 2     500
# 3     500
# Name: count, dtype: int64

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
y_train
# Out:
# array([2, 1, 0, ..., 3, 0, 1], shape=(2100,))

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_test=scale.fit_transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


knn=KNeighborsClassifier(n_neighbors=19)
nb=BernoulliNB()
svc=SVC()
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
Models=['KNN','Naive_Baies','Support_Vector_Machine','Decision_Tree','Random_Forest']
model_lst=[knn,nb,svc,dtc,rfc]

from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix,ConfusionMatrixDisplay



for i in range (len(model_lst)):
    print(Models[i])
    model=model_lst[i]
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print('Accuracy:',accuracy_score(y_test,y_pred))
    print('Precision:',precision_score(y_test,y_pred,average='weighted'))
    print('classification Report:',classification_report(y_test,y_pred))
    cm=confusion_matrix(y_test,y_pred)
    cmd=ConfusionMatrixDisplay(cm,display_labels=['2','1','0','3'])
    cmd.plot()
# Out:
# KNN
# Accuracy: 0.49666666666666665
# Precision: 0.4656829029449536
# classification Report:               precision    recall  f1-score   support
#
#            0       0.54      0.60      0.57       312
#            1       0.48      0.65      0.55       308
#            2       0.20      0.06      0.09       150
#            3       0.56      0.40      0.47       130
#
#     accuracy                           0.50       900
#    macro avg       0.45      0.43      0.42       900
# weighted avg       0.47      0.50      0.47       900
#
# Naive_Baies
# Accuracy: 0.5366666666666666
# Precision: 0.5446375166809588
# classification Report:               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.61       312
#            1       0.58      0.60      0.59       308
#            2       0.35      0.26      0.30       150
#            3       0.41      0.65      0.51       130
#
#     accuracy                           0.54       900
# ...

# %%
from sklearn.model_selection import GridSearchCV
para={'criterion':['gini','entropy','log_loss'],'n_estimators':[10,30,50,75,100,150],'random_state':[0,1,2,42,56]}
hyper=GridSearchCV(rfc,para,cv=6,scoring='accuracy')
hyper.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=6, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'n_estimators': [10, 30, 50, 75, 100, 150],
#                          'random_state': [0, 1, 2, 42, 56]},
#              scoring='accuracy')

# %%
print(hyper.best_params_)
# Out:
# {'criterion': 'entropy', 'n_estimators': 75, 'random_state': 2}

# %%
model2=RandomForestClassifier(criterion='entropy', n_estimators= 75,random_state= 2)
model2.fit(x_train,y_train)
y_pred2=model.predict(x_test)

# %%
print('Accuracy:',accuracy_score(y_test,y_pred2))
print('Precision:',precision_score(y_test,y_pred2,average='weighted'))
print('classification Report:',classification_report(y_test,y_pred2))
cm=confusion_matrix(y_test,y_pred2)
cmd=ConfusionMatrixDisplay(cm,display_labels=['2','1','0','3'])
cmd.plot()
# Out:
# Accuracy: 0.63
# Precision: 0.6293146297566505
# classification Report:               precision    recall  f1-score   support
#
#            0       0.67      0.68      0.68       312
#            1       0.62      0.67      0.64       308
#            2       0.59      0.34      0.43       150
#            3       0.59      0.77      0.67       130
#
#     accuracy                           0.63       900
#    macro avg       0.62      0.61      0.60       900
# weighted avg       0.63      0.63      0.62       900
